# %%
import requests
import pandas as pd
from PIL import Image
from io import BytesIO

# %%
data = pd.read_csv('schools_list_with_awards.csv')

# %%
data
# Out:
#     Roll Number                                       name  \
# 0        60010P                    Loreto Secondary School
# 1        60021U                  St Marys Secondary School
# 2        60030V                          Blackrock College
# 3        60040B                         Willow Park School
# 4        60041D                              Coláiste Eoin
# 5        60042F                          Coláiste Íosagáin
# 6        60050E                           Oatlands College
# 7        60070K                          Dominican College
# 8        60081P            Rockford Manor Secondary School
# 9        60090Q                            Rathdown School
# 10       60092U                           Clonkeen College
# 11       60100Q                        Castleknock College
# 12       60120W           Mount Sackville Secondary School
# 13       60121B                         Moyle Park College
# 14       60122D                             Coláiste Bríde
# ...

# %%
data = data.fillna('No Data')

# %%
data['Photo Reference1']
# Out:
# 0                                                No Data
# 1                                                No Data
# 2      CmRaAAAANyNTFr4EBASorHHWOKVqk2RS-3mq1-P75TOqpe...
# 3      CmRaAAAAdikncYRnfV_gd0aiM_IXFOkDPOhls3DVR4oDBr...
# 4      CmRaAAAAT-9jlurxVQzDIhfTyOpSMdQBii7UYjW4_gEtnZ...
# 5                                                No Data
# 6      CmRaAAAA_MFAo_3D1HtHsR8ra3Fl3-TTrXN3RGOmHtVu1-...
# 7      CmRaAAAAjBkkatG1_hXX0QD_yr6sb5aim_0zFQJxIp8Xee...
# 8      CmRaAAAAB4z3r2r7ue-vxb-oNX6w5uSNoNbb7-3AfnkmRP...
# 9      CmRaAAAAT7aFoc8nLYuF81Aup-fy-azR2mIUJ62F7Z_2sA...
# 10     CmRaAAAA3Q53bIPcRvt7eCy_-r4642fg_OBCic7kdu_JVV...
# 11     CmRaAAAAK5uAr3sqRKmYpphBe6KJMBF7j577p0FFkf9B5j...
# 12     CmRaAAAAQ8ME4xv8FgAbbar-XXAz-VGVqK4JMUDIn3YZbI...
# 13     CmRaAAAAowpKUm14N9lZyatrdHfTlDAur9OhtUVtrVxJRa...
# 14     CmRaAAAAhZqDhnJSagl-kS9VqcPInJY8CIU-PgQzMdKJNZ...
# 15     CmRaAAAAlfYb8y8BLXfs33YrdFuaf0VydZAYD-fvmJYxef...
# ...

# %%
for i in range(len(data['Photo Reference1'])):
    if data['Photo Reference1'][i] != 'No Data':
        school_image_url = ('https://maps.googleapis.com/maps/api/place/photo'
                        '?maxwidth=%s'
                        '&photoreference=%s'
                        '&key=%s') % (300, data['Photo Reference1'][i], 'AIzaSyDaJ1PrAzrf9wmP4pihZ3slQ8Apz0vm05g')
        print(i, school_image_url)
        retrieved_image = requests.get(school_image_url)
        print(retrieved_image)
        try:
            image = Image.open(BytesIO(retrieved_image.content))
            image.save(data['official_school_name'][i] + '.jpeg')
            print(data['official_school_name'][i])
        except:
            pass
    else:
        pass
# Out:
# 2 https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photoreference=CmRaAAAANyNTFr4EBASorHHWOKVqk2RS-3mq1-P75TOqpeZdvRoG0sWh24F0m-rzeMWZ7MwrpdY1KqxRz0drOC9QxAg07YBuHXfUlHfaX_n0gGlwqsntT3dnPS6vJFWdmVS-PPyuEhDkXxYaEMOMnIAjdyTz0KvEGhRe5Reg-wuGeanYJccoO77_uiIUgA&key=AIzaSyDaJ1PrAzrf9wmP4pihZ3slQ8Apz0vm05g
# <Response [200]>
# Blackrock College
# 3 https://maps.googleapis.com/maps/api/place/photo?maxwidth=300&photoreference=CmRaAAAAdikncYRnfV_gd0aiM_IXFOkDPOhls3DVR4oDBrHyPsxbw-2K5T5ihemy-KmsfDldaXrFNX6g86P8gXX8j4viQ6uHpCEsT49HSmYNFKcwpp4t4GfQ2hUKQmRbR_LPFgyQEhAlLz4yvLZFSYvh9soivGUGGhSd81_PE-c64pOq9AckBcPAOxyk9w&key=AIzaSyDaJ1PrAzrf9wmP4pihZ3slQ8Apz0vm05g
# <Response [200]>
# Willow Park School
# ...
